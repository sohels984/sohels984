# %% [markdown]
# <a href="https://colab.research.google.com/github/sohels984/sohels984/blob/main/airline_dataset_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df=pd.read_csv("/content/drive/MyDrive/MY DRIVE/PYTHON/DATASETS/Airline Dataset.csv")# Importing dataset.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df
# Out:
#        Passenger ID  First Name  Last Name  Gender  Age Nationality  \
# 0             10856      Edithe     Leggis  Female   62       Japan
# 1             43872      Elwood       Catt    Male   62   Nicaragua
# 2             42633       Darby    Felgate    Male   67      Russia
# 3             78493    Dominica       Pyle  Female   71       China
# 4             82072         Bay    Pencost    Male   21       China
# ...             ...         ...        ...     ...  ...         ...
# 98614         58454      Gareth    Mugford    Male   85       China
# 98615         22028       Kasey   Benedict  Female   19      Russia
# 98616         61732      Darrin     Lucken    Male   65   Indonesia
# 98617         19819       Gayle  Lievesley  Female   34       China
# 98618         14485  Wilhelmine     Touret  Female   10      Poland
#
#                       Airport Name Airport Country Code        Country Name  \
# ...

# %%
df.shape  # cheking the shape of dataset.
# Out:
# (98619, 15)

# %%
df.head(10)
# Out:
#    Passenger ID First Name Last Name  Gender  Age            Nationality  \
# 0         10856     Edithe    Leggis  Female   62                  Japan
# 1         43872     Elwood      Catt    Male   62              Nicaragua
# 2         42633      Darby   Felgate    Male   67                 Russia
# 3         78493   Dominica      Pyle  Female   71                  China
# 4         82072        Bay   Pencost    Male   21                  China
# 5         39630       Lora   Durbann  Female   55                 Brazil
# 6         11940       Rand      Bram    Male   73            Ivory Coast
# 7         26470   Perceval  Dallosso    Male   36                Vietnam
# 8         29447      Aleda    Pigram  Female   35  Palestinian Territory
# 9         75035     Burlie   Schustl    Male   13               Thailand
#
#                         Airport Name Airport Country Code    Country Name  \
# 0                   Coldfoot Airport                   US   United States
# ...

# %%
df.tail(10)
# Out:
#        Passenger ID  First Name  Last Name  Gender  Age Nationality  \
# 98609         70741     Olimpia    Arstall  Female   22       China
# 98610         87872         Che  Pressland    Male   83      France
# 98611         37761      Hadria     Vacher  Female   41      Canada
# 98612         26208         Ody    Tineman    Male   82   Indonesia
# 98613         95651      Oneida  Ossipenko  Female   47      Serbia
# 98614         58454      Gareth    Mugford    Male   85       China
# 98615         22028       Kasey   Benedict  Female   19      Russia
# 98616         61732      Darrin     Lucken    Male   65   Indonesia
# 98617         19819       Gayle  Lievesley  Female   34       China
# 98618         14485  Wilhelmine     Touret  Female   10      Poland
#
#                       Airport Name Airport Country Code        Country Name  \
# 98609  Wuzhou Changzhoudao Airport                   CN               China
# ...

# %%
df.isna().any(axis=0) # Cheking if any value is null in dataset.
# Out:
# Passenger ID            False
# First Name              False
# Last Name               False
# Gender                  False
# Age                     False
# Nationality             False
# Airport Name            False
# Airport Country Code    False
# Country Name            False
# Airport Continent       False
# Continents              False
# Departure Date          False
# Arrival Airport         False
# Pilot Name              False
# Flight Status           False
# dtype: bool

# %%
df.info()   # Checking the information about dataset.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98619 entries, 0 to 98618
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Passenger ID          98619 non-null  int64
#  1   First Name            98619 non-null  object
#  2   Last Name             98619 non-null  object
#  3   Gender                98619 non-null  object
#  4   Age                   98619 non-null  int64
#  5   Nationality           98619 non-null  object
#  6   Airport Name          98619 non-null  object
#  7   Airport Country Code  98619 non-null  object
#  8   Country Name          98619 non-null  object
#  9   Airport Continent     98619 non-null  object
#  10  Continents            98619 non-null  object
#  11  Departure Date        98619 non-null  object
#  12  Arrival Airport       98619 non-null  object
#  13  Pilot Name            98619 non-null  object
#  14  Flight Status         98619 non-null  object
# ...

# %%
df.describe() # Describing the dataset numeric values.
# Out:
#        Passenger ID           Age
# count  98619.000000  98619.000000
# mean   55168.689522     45.504021
# std    25985.443696     25.929849
# min    10000.000000      1.000000
# 25%    32608.000000     23.000000
# 50%    55338.000000     46.000000
# 75%    77695.000000     68.000000
# max    99999.000000     90.000000

# %%
df.columns
# Out:
# Index(['Passenger ID', 'First Name', 'Last Name', 'Gender', 'Age',
#        'Nationality', 'Airport Name', 'Airport Country Code', 'Country Name',
#        'Airport Continent', 'Continents', 'Departure Date', 'Arrival Airport',
#        'Pilot Name', 'Flight Status'],
#       dtype='object')

# %%
df.nunique()
# Out:
# Passenger ID            59871
# First Name               8437
# Last Name               41658
# Gender                      2
# Age                        90
# Nationality               240
# Airport Name             9062
# Airport Country Code      235
# Country Name              235
# Airport Continent           6
# Continents                  6
# Departure Date            364
# Arrival Airport          9024
# Pilot Name              98610
# Flight Status               3
# dtype: int64

# %% [markdown]
# # What is the distribution of passengers' gender?

# %%
df.Gender.value_counts()
# Out:
# Male      49598
# Female    49021
# Name: Gender, dtype: int64

# %%
df.Gender.value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# # •	What is the distribution of passengers' ages?

# %%
a=df.groupby(["Age","Gender"])['Gender'].size().unstack(fill_value=0)    #size()method that calculates the number of occurrences of each group when used with the groupby method.
a.reset_index(inplace=True)
a
# Out:
# Gender  Age  Female  Male
# 0         1     519   556
# 1         2     505   553
# 2         3     551   544
# 3         4     566   544
# 4         5     532   550
# ..      ...     ...   ...
# 85       86     516   552
# 86       87     533   531
# 87       88     545   524
# 88       89     516   615
# 89       90     525   551
#
# [90 rows x 3 columns]

# %%
bin=[1,25,50,70,90]
a["Age"]=pd.cut(a["Age"],bins=bin)
a
# Out:
# Gender           Age  Female  Male
# 0                NaN     519   556
# 1        (1.0, 25.0]     505   553
# 2        (1.0, 25.0]     551   544
# 3        (1.0, 25.0]     566   544
# 4        (1.0, 25.0]     532   550
# ..               ...     ...   ...
# 85      (70.0, 90.0]     516   552
# 86      (70.0, 90.0]     533   531
# 87      (70.0, 90.0]     545   524
# 88      (70.0, 90.0]     516   615
# 89      (70.0, 90.0]     525   551
#
# [90 rows x 3 columns]

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Age     89 non-null     category
#  1   Female  90 non-null     int64
#  2   Male    90 non-null     int64
# dtypes: category(1), int64(2)
# memory usage: 1.8 KB

# %%
b=a.groupby("Age")[['Female','Male']].sum()
b.sort_values(ascending=False,by='Female')
# Out:
# Gender    Female   Male
# Age
# (25, 50]   13608  13860
# (1, 25]    13059  13186
# (50, 70]   10984  11059
# (70, 90]   10851  10937

# %%
b["Total"]=b['Female']+b["Male"]
b
# Out:
# Gender    Female   Male  Total
# Age
# (1, 25]    13059  13186  26245
# (25, 50]   13608  13860  27468
# (50, 70]   10984  11059  22043
# (70, 90]   10851  10937  21788

# %%
b["Female%"]=b["Female"]/b["Total"]*100
b["Male%"]=b["Male"]/b["Total"]*100
b
# Out:
# Gender    Female   Male  Total    Female%      Male%
# Age
# (1, 25]    13059  13186  26245  49.758049  50.241951
# (25, 50]   13608  13860  27468  49.541284  50.458716
# (50, 70]   10984  11059  22043  49.829878  50.170122
# (70, 90]   10851  10937  21788  49.802644  50.197356

# %%
b.plot(kind='bar',figsize=(15,5))
# Out:
# <Axes: xlabel='Age'>

# %% [markdown]
# # •	What are the top nationalities among passengers?

# %%
df.columns
# Out:
# Index(['Passenger ID', 'First Name', 'Last Name', 'Gender', 'Age',
#        'Nationality', 'Airport Name', 'Airport Country Code', 'Country Name',
#        'Airport Continent', 'Continents', 'Departure Date', 'Arrival Airport',
#        'Pilot Name', 'Flight Status'],
#       dtype='object')

# %%
Nationality=df.groupby("Nationality")['Passenger ID'].count()
Nationality.nlargest(5)
# Out:
# Nationality
# China          18317
# Indonesia      10559
# Russia          5693
# Philippines     5239
# Brazil          3791
# Name: Passenger ID, dtype: int64

# %%
Nationality.nlargest(5).plot(kind='bar')
# Out:
# <Axes: xlabel='Nationality'>

# %% [markdown]
# # What is the most common country of origin for passengers?

# %%
mcco=df.groupby("Country Name")['Passenger ID'].count()
mcco.sort_values(ascending=False)
# Out:
# Country Name
# United States       22104
# Australia            6370
# Canada               5424
# Brazil               4504
# Papua New Guinea     4081
#                     ...
# Nauru                   7
# Monaco                  7
# Andorra                 7
# Palau                   5
# Jersey                  4
# Name: Passenger ID, Length: 235, dtype: int64

# %% [markdown]
# # The most common country of origin is United States.

# %% [markdown]
# # Are there any patterns in nationality and country of origin based on the airport or continent?

# %%
airport_nationality_group = df.groupby(['Airport Name', 'Nationality'])
continent_nationality_group = df.groupby(['Airport Continent', 'Nationality'])

# %%
nationality_counts_per_airport = airport_nationality_group['Nationality'].count()
nationality_counts_per_airport
# Out:
# Airport Name             Nationality
# 28 de Noviembre Airport  Belgium           1
#                          Brazil            2
#                          Cameroon          1
#                          China             7
#                          Czech Republic    1
#                                           ..
# Žilina Airport           China             2
#                          France            2
#                          Indonesia         2
#                          Japan             1
#                          Russia            1
# Name: Nationality, Length: 76812, dtype: int64

# %%
nationality_counts_per_continent = continent_nationality_group['Nationality'].count()
nationality_counts_per_continent
# Out:
# Airport Continent  Nationality
# AF                 Afghanistan          51
#                    Aland Islands         3
#                    Albania              46
#                    Andorra               2
#                    Angola               10
#                                         ..
# SAM                Vietnam              89
#                    Wallis and Futuna     1
#                    Yemen                30
#                    Zambia               11
#                    Zimbabwe              7
# Name: Nationality, Length: 1285, dtype: int64

# %% [markdown]
# # What are the most frequently visited airports?

# %%
most_frequently_visited_airport=df.groupby("Airport Name")['Passenger ID'].count()
most_frequently_visited_airport.sort_values(ascending=False)
# Out:
# Airport Name
# San Pedro Airport           43
# Santa Maria Airport         38
# Böblingen Flugfeld          36
# Santa Ana Airport           35
# San Fernando Airport        31
#                             ..
# Kar Kar Airport              2
# Balıkesir Merkez Airport     2
# J F Mitchell Airport         2
# Hiroshima Airport            1
# Falcon State Airport         1
# Name: Passenger ID, Length: 9062, dtype: int64

# %% [markdown]
# # 	Which countries and continents have the highest number of airports?

# %%
df.columns
# Out:
# Index(['Passenger ID', 'First Name', 'Last Name', 'Gender', 'Age',
#        'Nationality', 'Airport Name', 'Airport Country Code', 'Country Name',
#        'Airport Continent', 'Continents', 'Departure Date', 'Arrival Airport',
#        'Pilot Name', 'Flight Status'],
#       dtype='object')

# %%
heighest_number_of_airports=df.groupby(["Continents","Country Name"])['Airport Name'].count()
heighest_number_of_airports.sort_values(ascending=False)
# Out:
# Continents     Country Name
# North America  United States       22104
# Oceania        Australia            6370
# North America  Canada               5424
# South America  Brazil               4504
# Oceania        Papua New Guinea     4081
#                                    ...
# Europe         Andorra                 7
#                Monaco                  7
# Oceania        Nauru                   7
#                Palau                   5
# Europe         Jersey                  4
# Name: Airport Name, Length: 238, dtype: int64

# %% [markdown]
# # Are there airports with similar names in different countries?

# %%
from collections import Counter

# Find the counts of each airport name
airport_name_counts = Counter(df['Airport Name'])

# Filter names that appear more than once
similar_airport_names = [name for name, count in airport_name_counts.items() if count > 1]

# Find airports with the same name located in multiple countries
similar_airports = {}
for name in similar_airport_names:
    countries = df[df['Airport Name'] == name]['Country Name'].unique()
    if len(countries) > 1:
        similar_airports[name] = countries

# Print the results
for name, countries in similar_airports.items():
    print(f"Airport Name: {name}, Countries: {', '.join(countries)}")
# Out:
# Airport Name: Newcastle Airport, Countries: United Kingdom, South Africa, Australia
# Airport Name: St George Airport, Countries: Australia, United States
# Airport Name: Mendi Airport, Countries: Ethiopia, Papua New Guinea
# Airport Name: Mount Pleasant Airport, Countries: Falkland Islands (Malvinas), United States
# Airport Name: Herrera Airport, Countries: Dominican Republic, Colombia
# Airport Name: Santa Maria Airport, Countries: Brazil, Peru, Portugal
# Airport Name: Sawan Airport, Countries: Pakistan, Indonesia
# Airport Name: Moyale Airport, Countries: Ethiopia, Kenya
# Airport Name: Ceres Airport, Countries: Brazil, Argentina
# Airport Name: El Dorado Airport, Countries: Venezuela, Bolivarian Republic of, Argentina
# Airport Name: Faro Airport, Countries: Canada, Portugal
# Airport Name: Queenstown Airport, Countries: Australia, South Africa
# Airport Name: San Fernando Airport, Countries: Philippines, United States, Argentina
# ...

# %% [markdown]
# # What is the distribution of departure dates?

# %%
df.columns
# Out:
# Index(['Passenger ID', 'First Name', 'Last Name', 'Gender', 'Age',
#        'Nationality', 'Airport Name', 'Airport Country Code', 'Country Name',
#        'Airport Continent', 'Continents', 'Departure Date', 'Arrival Airport',
#        'Pilot Name', 'Flight Status'],
#       dtype='object')

# %%
departure_dates=df.groupby("Departure Date")['Passenger ID'].count()

# %%
departure_dates
# Out:
# Departure Date
# 1/1/2022     267
# 1/10/2022    278
# 1/11/2022    263
# 1/12/2022    281
# 1/13/2022    301
#             ...
# 9/5/2022     272
# 9/6/2022     272
# 9/7/2022     282
# 9/8/2022     287
# 9/9/2022     268
# Name: Passenger ID, Length: 364, dtype: int64

# %%
type(departure_dates)
# Out:
# pandas.core.series.Series

# %%
dfdd = departure_dates.to_frame(name='date_count')
dfdd.reset_index(inplace=True)
dfdd
# Out:
#     Departure Date  date_count
# 0         1/1/2022         267
# 1        1/10/2022         278
# 2        1/11/2022         263
# 3        1/12/2022         281
# 4        1/13/2022         301
# ..             ...         ...
# 359       9/5/2022         272
# 360       9/6/2022         272
# 361       9/7/2022         282
# 362       9/8/2022         287
# 363       9/9/2022         268
#
# [364 rows x 2 columns]

# %%
dfdd.columns
# Out:
# Index(['Departure Date', 'date_count'], dtype='object')

# %%
from datetime import datetime
dfdd['Departure Date'] = pd.to_datetime(dfdd['Departure Date'])
bins = [
    datetime(2022, 1, 1),
    datetime(2022, 1, 31),
    datetime(2022, 2, 28),
    datetime(2022, 3, 31),
    datetime(2022, 4, 30),
    datetime(2022, 5, 31),
    datetime(2022, 6, 30),
    datetime(2022, 7, 31),
    datetime(2022, 8, 31),
    datetime(2022, 9, 30),
    datetime(2022, 10, 31),
    datetime(2022, 11, 30),
    datetime(2022, 12, 31)
]
dfdd['Date_Binned'] = pd.cut(dfdd['Departure Date'], bins)
dfdd
# Out:
#     Departure Date  date_count               Date_Binned
# 0       2022-01-01         267                       NaN
# 1       2022-01-10         278  (2022-01-01, 2022-01-31]
# 2       2022-01-11         263  (2022-01-01, 2022-01-31]
# 3       2022-01-12         281  (2022-01-01, 2022-01-31]
# 4       2022-01-13         301  (2022-01-01, 2022-01-31]
# ..             ...         ...                       ...
# 359     2022-09-05         272  (2022-08-31, 2022-09-30]
# 360     2022-09-06         272  (2022-08-31, 2022-09-30]
# 361     2022-09-07         282  (2022-08-31, 2022-09-30]
# 362     2022-09-08         287  (2022-08-31, 2022-09-30]
# 363     2022-09-09         268  (2022-08-31, 2022-09-30]
#
# [364 rows x 3 columns]

# %% [markdown]
# # Distribution of departure dates.

# %%
dfdd.groupby("Date_Binned")['date_count'].sum()
# Out:
# Date_Binned
# (2022-01-01, 2022-01-31]    8149
# (2022-01-31, 2022-02-28]    7653
# (2022-02-28, 2022-03-31]    8431
# (2022-03-31, 2022-04-30]    7959
# (2022-04-30, 2022-05-31]    8496
# (2022-05-31, 2022-06-30]    8128
# (2022-06-30, 2022-07-31]    8451
# (2022-07-31, 2022-08-31]    8544
# (2022-08-31, 2022-09-30]    8149
# (2022-09-30, 2022-10-31]    8415
# (2022-10-31, 2022-11-30]    8053
# (2022-11-30, 2022-12-31]    7924
# Name: date_count, dtype: int64

# %% [markdown]
# # How many flights are in each flight status category (e.g., delayed, on time)?

# %%
df.columns
# Out:
# Index(['Passenger ID', 'First Name', 'Last Name', 'Gender', 'Age',
#        'Nationality', 'Airport Name', 'Airport Country Code', 'Country Name',
#        'Airport Continent', 'Continents', 'Departure Date', 'Arrival Airport',
#        'Pilot Name', 'Flight Status'],
#       dtype='object')

# %%
flight_status=df.groupby("Flight Status")['Flight Status'].count()
flight_status
# Out:
# Flight Status
# Cancelled    32942
# Delayed      32831
# On Time      32846
# Name: Flight Status, dtype: int64

# %%
flight_status.plot(kind='bar')
# Out:
# <Axes: xlabel='Flight Status'>

# %% [markdown]
# # Are there any trends in flight statuses over time?

# %%
status_category=df.groupby(["Departure Date","Flight Status"])['Flight Status'].size().unstack(fill_value=0)
status_category.reset_index(inplace=True)
status_category
# Out:
# Flight Status Departure Date  Cancelled  Delayed  On Time
# 0                   1/1/2022         91       92       84
# 1                  1/10/2022         97       95       86
# 2                  1/11/2022         80      100       83
# 3                  1/12/2022         95       84      102
# 4                  1/13/2022         96      103      102
# ..                       ...        ...      ...      ...
# 359                 9/5/2022        112       89       71
# 360                 9/6/2022         91       95       86
# 361                 9/7/2022         95       86      101
# 362                 9/8/2022         96       93       98
# 363                 9/9/2022         76       99       93
#
# [364 rows x 4 columns]

# %%
status_category['Date_Binned'] = pd.cut(dfdd['Departure Date'], bins)
status_category
# Out:
# Flight Status Departure Date  Cancelled  Delayed  On Time  \
# 0                   1/1/2022         91       92       84
# 1                  1/10/2022         97       95       86
# 2                  1/11/2022         80      100       83
# 3                  1/12/2022         95       84      102
# 4                  1/13/2022         96      103      102
# ..                       ...        ...      ...      ...
# 359                 9/5/2022        112       89       71
# 360                 9/6/2022         91       95       86
# 361                 9/7/2022         95       86      101
# 362                 9/8/2022         96       93       98
# 363                 9/9/2022         76       99       93
#
# Flight Status               Date_Binned
# 0                                   NaN
# 1              (2022-01-01, 2022-01-31]
# 2              (2022-01-01, 2022-01-31]
# 3              (2022-01-01, 2022-01-31]
# 4              (2022-01-01, 2022-01-31]
# ...

# %%
an=status_category.groupby("Date_Binned").sum()
an
# Out:
# <ipython-input-45-0bf91635c91e>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   an=status_category.groupby("Date_Binned").sum()
# Flight Status             Cancelled  Delayed  On Time
# Date_Binned
# (2022-01-01, 2022-01-31]       2656     2776     2717
# (2022-01-31, 2022-02-28]       2565     2537     2551
# (2022-02-28, 2022-03-31]       2776     2794     2861
# (2022-03-31, 2022-04-30]       2645     2715     2599
# (2022-04-30, 2022-05-31]       2846     2853     2797
# (2022-05-31, 2022-06-30]       2756     2678     2694
# (2022-06-30, 2022-07-31]       2800     2778     2873
# (2022-07-31, 2022-08-31]       2864     2805     2875
# (2022-08-31, 2022-09-30]       2766     2723     2660
# (2022-09-30, 2022-10-31]       2797     2775     2843
# ...

# %% [markdown]
# # Not a big trend found among statuses.

# %%
an.plot(kind='bar',figsize=(15,6))
# Out:
# <Axes: xlabel='Date_Binned'>

# %%
an.plot(figsize=(15,6))
# Out:
# <Axes: xlabel='Date_Binned'>

# %% [markdown]
# # Who are the most frequently mentioned pilots?

# %%
pc=df.groupby("Pilot Name")['Pilot Name'].count()
pc.sort_values(ascending=False)
# Out:
# Pilot Name
# Ollie Sidle              2
# Rance Evetts             2
# Christabella Reubbens    2
# Damian Garnsey           2
# Brig Shuxsmith           2
#                         ..
# Evelina Antonias         1
# Evelin Walster           1
# Evelin Vasyaev           1
# Evelin Tison             1
# Zuzana Wingrove          1
# Name: Pilot Name, Length: 98610, dtype: int64

# %% [markdown]
# # I could not find any pilot whose name appeared more than 2 times. Therefore, there is no pilot whom we can name most frequently.

# %%
df.columns
# Out:
# Index(['Passenger ID', 'First Name', 'Last Name', 'Gender', 'Age',
#        'Nationality', 'Airport Name', 'Airport Country Code', 'Country Name',
#        'Airport Continent', 'Continents', 'Departure Date', 'Arrival Airport',
#        'Pilot Name', 'Flight Status'],
#       dtype='object')

# %% [markdown]
# # What is the distribution of passengers across different continents?

# %%
pc=df.groupby("Continents")['Passenger ID'].count()
pc.sort_values(ascending=False)
# Out:
# Continents
# North America    32033
# Asia             18637
# Oceania          13866
# Europe           12335
# Africa           11030
# South America    10718
# Name: Passenger ID, dtype: int64

# %% [markdown]
# # How do flight statuses vary across continents?

# %%
flight_status_over_continents=df.groupby(["Continents","Flight Status"])['Flight Status'].size().unstack(fill_value=0)
flight_status_over_continents
# Out:
# Flight Status  Cancelled  Delayed  On Time
# Continents
# Africa              3657     3654     3719
# Asia                6235     6160     6242
# Europe              4095     4178     4062
# North America      10693    10696    10644
# Oceania             4619     4634     4613
# South America       3643     3509     3566

# %%
flight_status_over_continents.plot(kind='bar')
# Out:
# <Axes: xlabel='Continents'>

# %% [markdown]
# Based on the exploratory data analysis conducted on the airline database, several insights have been uncovered:
#
# **Gender Distribution:** The dataset shows an almost equal distribution between male and female passengers. This suggests that the airline industry caters to a diverse range of travelers in terms of gender.
#
# **Age Distribution:** Most passengers fall within the age group of 25 to 50 years old. This indicates that the airline's services are popular among adults in their prime working and traveling years.
#
# **Nationality Insights:** Chinese and Indonesian nationalities dominate the dataset, implying a significant number of travelers from these countries.
#
# **Country of Origin:** The United States ranks as the top country of origin for travelers, indicating a high volume of inbound travelers, possibly due to its status as a major international travel hub.
#
# **Travel Patterns:** The prevalence of Chinese and Indonesian passengers, along with the high number of United States-originating flights, suggests a strong connection between these countries and North America.
#
# **Airport Distribution:** The dataset contains information on a vast number of airports, with the United States having the most airports (22104). Additionally, it's noteworthy that 40 airports share the same name but are located in different countries, highlighting the global reach of these airports.
#
# **Monthly Flight Distribution:** August emerges as the busiest month for flights. However, the data suggests that flight operations remain relatively consistent across the other months.
#
# **Flight Status:** The dataset reveals that the quantities of flight statuses (cancelled, on time, and delayed) are roughly equal. This indicates that the airline industry faces a similar distribution of these statuses, and a substantial portion of flights may experience delays or cancellations.
#
#
# ***In summary, the exploratory data analysis has shed light on various aspects of the airline industry, including passenger demographics, travel patterns, airport distribution, and flight statuses. These insights can inform strategic decisions and improvements within the airline industry to enhance customer experiences and operational efficiency.***
